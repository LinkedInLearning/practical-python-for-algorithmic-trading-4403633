# %% [markdown]
# # Smart Optimization to Save Computing Time

# %%
???

# %% [markdown]
# <table style="width:100%; height:90%">
#       <tr>
#     <th>Grid Search</th>
#     <th>Smart Search</th>
#   </tr>
#   <tr>
#     <td><img src="src/07_Table_Optimize BG Default Defaults.png" alt="Optimizing Limits' Parameters" style="width:100%"></td>
#     <td><img src="src/08_Table_Smart Optimization.png" alt="Parametrize the Strategy" style="width:100%"></td>
#   </tr>
# </table>

# %% [markdown]
# ## Load the model

# %%
import pickle

# %%
with open('models/model_dt_regression.pkl', 'rb') as f:
    model_dt = pickle.load(f)
# Out:
# /Users/sota/miniforge3/envs/backtesting/lib/python3.11/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.2.2 when using version 1.1.3. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
model_dt
# Out:
# DecisionTreeRegressor(max_depth=15)

# %% [markdown]
# ## Load the data

# %%
import pandas as pd

df = pd.read_excel('data/Microsoft_LinkedIn_Processed.xlsx', index_col=0, parse_dates=['Date'])
df
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2016-12-08   56.325228   56.582507   55.902560   56.058762  21220800
# 2016-12-09   56.214968   56.959234   56.169027   56.940857  27349400
# ...                ...         ...         ...         ...       ...
# 2023-03-14  256.750000  261.070007  255.860001  260.790009  33620300
# 2023-03-15  259.980011  266.480011  259.209991  265.440002  46028000
#
#             change_tomorrow change_tomorrow_direction
# Date
# 2016-12-08         1.549143                        UP
# 2016-12-09         0.321692                        UP
# ...                     ...                       ...
# 2023-03-14         1.751806                        UP
# 2023-03-15         3.895731                        UP
#
# [1576 rows x 7 columns]

# %% [markdown]
# ## Parametrize & optimize the investment strategy

# %% [markdown]
# ### Create Strategy class

# %%
from backtesting import Strategy

# %%
class Regression(Strategy):
    limit_buy = 1
    limit_sell = -5
    
    def init(self):
        self.model = model_dt
        self.already_bought = False

    def next(self):
        explanatory_today = self.data.df.iloc[[-1], :]
        forecast_tomorrow = self.model.predict(explanatory_today)[0]
        
        if forecast_tomorrow > self.limit_buy and self.already_bought == False:
            self.buy()
            self.already_bought = True
        elif forecast_tomorrow < self.limit_sell and self.already_bought == True:
            self.sell()
            self.already_bought = False
        else:
            pass

# %% [markdown]
# ### Create `Backtest` class

# %%
from backtesting import Backtest

# %%
df_explanatory = df[['Open', 'High', 'Low', 'Close', 'Volume']].copy()

# %%
bt = Backtest(df_explanatory, SimpleRegression,
              cash=10000, commission=.002, exclusive_orders=True)

# %% [markdown]
# ### Optimize backtesting with multiple combinations

# %%
import multiprocessing as mp
mp.set_start_method('fork')

# %%
stats_skopt, heatmap, optimize_result = bt.optimize(
    limit_buy=[0, 10],
    limit_sell=[-10, 0],
    maximize='Return [%]',
    method='skopt',
    max_tries=500,
    random_state=0,
    return_heatmap=True,
    return_optimization=True)
# Out:
# CPU times: user 17.1 s, sys: 91 ms, total: 17.1 s
# Wall time: 17.5 s

# %% [markdown]
# ### Which are the best values for the parameters?

# %%
dff = heatmap.reset_index()
dff = dff.pivot(index='limit_buy', columns='limit_sell', values='Return [%]')
dff

# %%
dff.style.highlight_null(props='background-color: transparent; color: transparent')
# Out:
# <style type="text/css">
# #T_38d53_row0_col0, #T_38d53_row0_col2, #T_38d53_row0_col3, #T_38d53_row0_col4, #T_38d53_row0_col5, #T_38d53_row0_col6, #T_38d53_row0_col7, #T_38d53_row0_col8, #T_38d53_row0_col10, #T_38d53_row1_col0, #T_38d53_row1_col1, #T_38d53_row1_col2, #T_38d53_row1_col4, #T_38d53_row1_col6, #T_38d53_row1_col7, #T_38d53_row1_col8, #T_38d53_row1_col10, #T_38d53_row2_col0, #T_38d53_row2_col1, #T_38d53_row2_col2, #T_38d53_row2_col3, #T_38d53_row2_col5, #T_38d53_row2_col7, #T_38d53_row2_col9, #T_38d53_row3_col0, #T_38d53_row3_col1, #T_38d53_row3_col3, #T_38d53_row3_col4, #T_38d53_row3_col5, #T_38d53_row3_col6, #T_38d53_row3_col8, #T_38d53_row3_col10, #T_38d53_row4_col1, #T_38d53_row4_col2, #T_38d53_row4_col3, #T_38d53_row4_col4, #T_38d53_row4_col5, #T_38d53_row4_col6, #T_38d53_row4_col9, #T_38d53_row4_col10, #T_38d53_row5_col0, #T_38d53_row5_col1, #T_38d53_row5_col2, #T_38d53_row5_col3, #T_38d53_row5_col4, #T_38d53_row5_col6, #T_38d53_row5_col7, #T_38d53_row5_col8, #T_38d53_row6_col0, #T_38d53_row6_col2, #T_38d53_row6_col3, #T_38d53_row6_col4, #T_38d53_row6_col5, #T_38d53_row6_col6, #T_38d53_row6_col7, #T_38d53_row6_col8, #T_38d53_row6_col9, #T_38d53_row6_col10, #T_38d53_row7_col0, #T_38d53_row7_col2, #T_38d53_row7_col4, #T_38d53_row7_col5, #T_38d53_row7_col6, #T_38d53_row7_col7, #T_38d53_row7_col8, #T_38d53_row7_col9, #T_38d53_row8_col0, #T_38d53_row8_col1, #T_38d53_row8_col2, #T_38d53_row8_col3, #T_38d53_row8_col6, #T_38d53_row8_col8, #T_38d53_row8_col9, #T_38d53_row8_col10, #T_38d53_row9_col0, #T_38d53_row9_col1, #T_38d53_row9_col4, #T_38d53_row9_col5, #T_38d53_row9_col6, #T_38d53_row9_col8, #T_38d53_row9_col9, #T_38d53_row9_col10, #T_38d53_row10_col0, #T_38d53_row10_col1, #T_38d53_row10_col2, #T_38d53_row10_col3, #T_38d53_row10_col5, #T_38d53_row10_col6, #T_38d53_row10_col7, #T_38d53_row10_col8, #T_38d53_row10_col9, #T_38d53_row10_col10 {
#   background-color: transparent;
#   color: transparent;
# }
# </style>
# <table id="T_38d53">
#   <thead>
#     <tr>
#       <th class="index_name level0" >limit_sell</th>
#       <th id="T_38d53_level0_col0" class="col_heading level0 col0" >-10</th>
#       <th id="T_38d53_level0_col1" class="col_heading level0 col1" >-9</th>
#       <th id="T_38d53_level0_col2" class="col_heading level0 col2" >-8</th>
#       <th id="T_38d53_level0_col3" class="col_heading level0 col3" >-7</th>
#       <th id="T_38d53_level0_col4" class="col_heading level0 col4" >-6</th>
#       <th id="T_38d53_level0_col5" class="col_heading level0 col5" >-5</th>
#       <th id="T_38d53_level0_col6" class="col_heading level0 col6" >-4</th>
#       <th id="T_38d53_level0_col7" class="col_heading level0 col7" >-3</th>
#       <th id="T_38d53_level0_col8" class="col_heading level0 col8" >-2</th>
#       <th id="T_38d53_level0_col9" class="col_heading level0 col9" >-1</th>
#       <th id="T_38d53_level0_col10" class="col_heading level0 col10" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >limit_buy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38d53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38d53_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_38d53_row0_col1" class="data row0 col1" >337.745113</td>
#       <td id="T_38d53_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_38d53_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_38d53_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_38d53_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_38d53_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_38d53_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_38d53_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_38d53_row0_col9" class="data row0 col9" >11721.523635</td>
#       <td id="T_38d53_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_38d53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38d53_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_38d53_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_38d53_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_38d53_row1_col3" class="data row1 col3" >295.350207</td>
#       <td id="T_38d53_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_38d53_row1_col5" class="data row1 col5" >448.287855</td>
#       <td id="T_38d53_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_38d53_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_38d53_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_38d53_row1_col9" class="data row1 col9" >2529.445178</td>
#       <td id="T_38d53_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_38d53_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38d53_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_38d53_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_38d53_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_38d53_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_38d53_row2_col4" class="data row2 col4" >215.076395</td>
#       <td id="T_38d53_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_38d53_row2_col6" class="data row2 col6" >440.224724</td>
#       <td id="T_38d53_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_38d53_row2_col8" class="data row2 col8" >390.127920</td>
#       <td id="T_38d53_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_38d53_row2_col10" class="data row2 col10" >-3.137514</td>
#     </tr>
#     <tr>
#       <th id="T_38d53_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38d53_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_38d53_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_38d53_row3_col2" class="data row3 col2" >204.955270</td>
#       <td id="T_38d53_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_38d53_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_38d53_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_38d53_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_38d53_row3_col7" class="data row3 col7" >268.790120</td>
#       <td id="T_38d53_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_38d53_row3_col9" class="data row3 col9" >-45.846707</td>
#       <td id="T_38d53_row3_col10" class="data row3 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_38d53_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38d53_row4_col0" class="data row4 col0" >191.296430</td>
#       <td id="T_38d53_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_38d53_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_38d53_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_38d53_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_38d53_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_38d53_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_38d53_row4_col7" class="data row4 col7" >-72.062746</td>
#       <td id="T_38d53_row4_col8" class="data row4 col8" >-74.879463</td>
#       <td id="T_38d53_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_38d53_row4_col10" class="data row4 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_38d53_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38d53_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_38d53_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_38d53_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_38d53_row5_col3" class="data row5 col3"

# %%
import numpy as np

# %%
dff.sort_index(axis=1, ascending=False)\
    .style.format(precision=0)\
    .background_gradient(vmin=np.nanmin(dff), vmax=np.nanmax(dff))\
    .highlight_null(props='background-color: transparent; color: transparent')
# Out:
# <style type="text/css">
# #T_9f616_row0_col0, #T_9f616_row0_col2, #T_9f616_row0_col3, #T_9f616_row0_col4, #T_9f616_row0_col5, #T_9f616_row0_col6, #T_9f616_row0_col7, #T_9f616_row0_col8, #T_9f616_row0_col10, #T_9f616_row1_col0, #T_9f616_row1_col2, #T_9f616_row1_col3, #T_9f616_row1_col4, #T_9f616_row1_col6, #T_9f616_row1_col8, #T_9f616_row1_col9, #T_9f616_row1_col10, #T_9f616_row2_col1, #T_9f616_row2_col3, #T_9f616_row2_col5, #T_9f616_row2_col7, #T_9f616_row2_col8, #T_9f616_row2_col9, #T_9f616_row2_col10, #T_9f616_row3_col0, #T_9f616_row3_col2, #T_9f616_row3_col4, #T_9f616_row3_col5, #T_9f616_row3_col6, #T_9f616_row3_col7, #T_9f616_row3_col9, #T_9f616_row3_col10, #T_9f616_row4_col0, #T_9f616_row4_col1, #T_9f616_row4_col4, #T_9f616_row4_col5, #T_9f616_row4_col6, #T_9f616_row4_col7, #T_9f616_row4_col8, #T_9f616_row4_col9, #T_9f616_row5_col2, #T_9f616_row5_col3, #T_9f616_row5_col4, #T_9f616_row5_col6, #T_9f616_row5_col7, #T_9f616_row5_col8, #T_9f616_row5_col9, #T_9f616_row5_col10, #T_9f616_row6_col0, #T_9f616_row6_col1, #T_9f616_row6_col2, #T_9f616_row6_col3, #T_9f616_row6_col4, #T_9f616_row6_col5, #T_9f616_row6_col6, #T_9f616_row6_col7, #T_9f616_row6_col8, #T_9f616_row6_col10, #T_9f616_row7_col1, #T_9f616_row7_col2, #T_9f616_row7_col3, #T_9f616_row7_col4, #T_9f616_row7_col5, #T_9f616_row7_col6, #T_9f616_row7_col8, #T_9f616_row7_col10, #T_9f616_row8_col0, #T_9f616_row8_col1, #T_9f616_row8_col2, #T_9f616_row8_col4, #T_9f616_row8_col7, #T_9f616_row8_col8, #T_9f616_row8_col9, #T_9f616_row8_col10, #T_9f616_row9_col0, #T_9f616_row9_col1, #T_9f616_row9_col2, #T_9f616_row9_col4, #T_9f616_row9_col5, #T_9f616_row9_col6, #T_9f616_row9_col9, #T_9f616_row9_col10, #T_9f616_row10_col0, #T_9f616_row10_col1, #T_9f616_row10_col2, #T_9f616_row10_col3, #T_9f616_row10_col4, #T_9f616_row10_col5, #T_9f616_row10_col7, #T_9f616_row10_col8, #T_9f616_row10_col9, #T_9f616_row10_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: transparent;
#   color: transparent;
# }
# #T_9f616_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9f616_row0_col9 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_9f616_row1_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_9f616_row1_col5, #T_9f616_row2_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_9f616_row1_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_9f616_row2_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_9f616_row2_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_9f616_row2_col6, #T_9f616_row3_col8, #T_9f616_row4_col10, #T_9f616_row6_col9, #T_9f616_row7_col9 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_9f616_row3_col1, #T_9f616_row8_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_9f616_row3_col3, #T_9f616_row7_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_9f616_row4_col2, #T_9f616_row4_col3, #T_9f616_row5_col0, #T_9f616_row5_col1, #T_9f616_row7_col0, #T_9f616_row8_col3, #T_9f616_row9_col3, #T_9f616_row9_col7, #T_9f616_row9_col8, #T_9f616_row10_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9f616_row5_col5, #T_9f616_row8_col6 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_9f616">
#   <thead>
#     <tr>
#       <th class="index_name level0" >limit_sell</th>
#       <th id="T_9f616_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9f616_level0_col1" class="col_heading level0 col1" >-1</th>
#       <th id="T_9f616_level0_col2" class="col_heading level0 col2" >-2</th>
#       <th id="T_9f616_level0_col3" class="col_heading level0 col3" >-3</th>
#       <th id="T_9f616_level0_col4" class="col_heading level0 col4" >-4</th>
#       <th id="T_9f616_level0_col5" class="col_heading level0 col5" >-5</th>
#       <th id="T_9f616_level0_col6" class="col_heading level0 col6" >-6</th>
#       <th id="T_9f616_level0_col7" class="col_heading level0 col7" >-7</th>
#       <th id="T_9f616_level0_col8" class="col_heading level0 col8" >-8</th>
#       <th id="T_9f616_level0_col9" class="col_heading level0 col9" >-9</th>
#       <th id="T_9f616_level0_col10" class="col_heading level0 col10" >-10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >limit_buy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f616_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f616_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_9f616_row0_col1" class="data row0 col1" >11722</td>
#       <td id="T_9f616_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_9f616_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_9f616_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_9f616_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_9f616_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_9f616_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_9f616_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_9f616_row0_col9" class="data row0 col9" >338</td>
#       <td id="T_9f616_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9f616_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f616_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_9f616_row1_col1" class="data row1 col1" >2529</td>
#       <td id="T_9f616_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_9f616_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_9f616_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_9f616_row1_col5" class="data row1 col5" >448</td>
#       <td id="T_9f616_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_9f616_row1_col7" class="data row1 col7" >295</td>
#       <td id="T_9f616_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_9f616_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_9f616_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9f616_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9f616_row2_col0" class="data row2 col0" >-3</td>
#       <td id="T_9f616_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_9f616_row2_col2" class="data row2 col2" >390</td>
#       <td id="T_9f616_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_9f616_row2_col4" class="data row2 col4" >440</td>
#       <td id="T_9f616_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_9f616_row2_col6" class="data row2 col6" >215</td>
#       <td id="T_9f616_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_9f616_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_9f616_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_9f616_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9f616_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9f616_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_9f616_row3_col1" class="data row3 col1" >-46</td>
#       <td id="T_9f616_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_9f616_row3_col3" class="data row3 col3" >269</td>
#       <td id="T_9f616_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_9f616_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_9f616_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_9f616_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_9f616_row3_col8" class="data row3 col8" >205</td>
#       <td id="T_9f616_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_9f616_row3_col10" class="data row3 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9f616_lev

# %% [markdown]
# ### How to interpret smart optimization?

# %% [markdown]
# #### Number of evaluations

# %% [markdown]
# https://kernc.github.io/backtesting.py/doc/examples/Parameter%20Heatmap%20&%20Optimization.html

# %%
from skopt.plots import plot_evaluations

_ = plot_evaluations(optimize_result, bins=10)

# %% [markdown]
# #### Density

# %%
from skopt.plots import plot_objective

_ = plot_objective(optimize_result, n_points=10)

# %% [markdown]
# ## Practice to master the knowledge
#
# Work on the challenge with another dataset:
#
# 1. Learn the <a>mental models</a> to solve the challenge faster.
# 2. Complete the <a href="08D_Smart Optimization to Save Computing Time.ipynb">notebook</a>.
